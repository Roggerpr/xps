# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import glob
import os
import peakutils
import datetime
import warnings
from jupyterthemes import jtplot

import logging

# %%
logging.getLogger().setLevel(logging.CRITICAL)
warnings.filterwarnings("ignore")

from xps.xps_sw import *
from xps.xps_import import *
from xps.xps_analysis import *
from xps.xps_bg import *

jtplot.style('default', grid=False)
plt.rcParams['errorbar.capsize'] = 8
plt.rcParams['font.size'] = 18
plt.rc('font', size= 18)
plt.rc('legend', fontsize= 15)
plt.rc('xtick', labelsize= 18)
plt.rc('ytick', labelsize= 18)
plt.rc('axes', labelsize=18)
plt.rc('axes', titlesize=18)

# %%
asf = dict({'C1s' : 0.296, 'O1s' : 0.711, 'N1s' : 0.477, 'Ba3d' : 7.49,
            'Br3p' : 1.054, 'Br3d' : 1.054,
           'In3d' : 4.359, 'Sn3d' : 4.725, 'Cl2p' : 0.891, 'Si2p': 0.339})

# %% [markdown]
# # Analysis experiments on Cu from January/February 2021

# %% [markdown]
# ## Read processed experiments

# %%
path = '/Users/pabloherrero/sabat/xps_spectra/ITO_FBI/qITO_subl/**/*.uxy'

files = glob.glob(path, recursive=True)
files.sort()

files
# Out:
# ['/Users/pabloherrero/sabat/xps_spectra/ITO_FBI/qITO_subl/2021_04_15_qITO/proc/20210415_1-qITO_FBI_subl_60min.uxy',
#  '/Users/pabloherrero/sabat/xps_spectra/ITO_FBI/qITO_subl/2021_04_15_qITO/proc/20210415_1-qITO_as_received.uxy',
#  '/Users/pabloherrero/sabat/xps_spectra/ITO_FBI/qITO_subl/2021_04_15_qITO/proc/20210415_1-qITO_clean.uxy']

# %%
fbi_exps = [read_processed_xp(f) for f in files]

# %%
fbi_exps = []
ba_exps = []
for f in files:
    if ('FBI_subl_' in f) and ('BaCl2' not in f):
        fbi_exps.append(read_processed_xp(f))
    elif 'BaCl2' in f:
        ba_exps.append(read_processed_xp(f))

clean_exps = []
for f in files:
    if 'clean' in f:
        clean_exps.append(read_processed_xp(f))

# %% [markdown]
# ## Integrate areas

# %% [markdown]
# ### C 1s

# %%
region = 'C1s'
integrateRegions(fbi_exps, region, indRef=0, asf=asf)
# Out:
# [3149.1274602577864, 3880.710774513089, 873.7400764000271]

# %% [markdown]
# ### O 1s

# %%
region = 'O1s'
integrateRegions(fbi_exps, region, indRef=1, asf=asf)
# Out:
# [10280.264172696976, 10468.131596571016, 12942.719105828368]

# %% [markdown]
# ### N 1s

# %%
region = 'N1s'
integrateRegions(fbi_exps, region, indRef=0, asf=asf)
# Out:
# [648.7758094943637, 92.46544515366116, 93.49104107163946]

# %% [markdown]
# ### Si 2p

# %%
region = 'Si2p'
integrateRegions(fbi_exps, region, indRef=0, asf=asf)
# Out:
# [425.1928404846684, 660.3480154030783, 264.1226303504308]

# %% [markdown]
# ### In 3d

# %%
region = 'In3d'
integrateRegions(fbi_exps, region, indRef=0, asf=asf)
# Out:
# [59458.476839068404, 46347.127744532, 90873.71186355167]

# %% [markdown]
# ### Sn 3d

# %%
region = 'Sn3d'
integrateRegions(fbi_exps, region, indRef=0, asf=asf)
# Out:
# [6953.589697715006, 8125.832169119977, 9286.28261217745]

# %% [markdown]
# # Stoichiometry

# %%
num, denom = (('N1s', 'C1s', 'C1s'), ('O1s', 'N1s', 'O1s'))
make_stoichometry_table(fbi_exps,  num=num, denom=denom, sep=' \t ')
# Out:
# Experiment	N/O	C/N	C/O
# 1-qITO_FBI_subl_60min 	 0.09  	  7.82  	  0.74
# 1-qITO_as_received 	 0.07  	  12.06  	  0.89
# 1-qITO_clean 	 0.07  	  2.44  	  0.16

# %%
num, denom = (('In3d', 'In3d'), ('O1s', 'Sn3d'))
make_stoichometry_table(fbi_exps,  num=num, denom=denom, sep=' \t ')
# Out:
# Experiment	In/O	In/Sn
# 1-qITO_FBI_subl_60min 	 0.94  	  9.27
# 1-qITO_as_received 	 0.72  	  6.18
# 1-qITO_clean 	 1.15  	  10.61

# %%
print('Nominal')
print('N/O \t C/N \t \t C/O \t Ba/Cl')
print(3/5, '\t', '%.3f'%(31/3), '\t', '%.3f' %(31/5), '\t %.3f' %2 )
# Out:
# Nominal
# N/O 	 C/N 	 	 C/O 	 Ba/Cl
# 0.6 	 10.333 	 6.200 	 2.000

# %% [markdown]
# # Coverages

# %% [markdown]
# ### Convert to layer scale

# %% [markdown]
# $$ I_f = (1-x)I_0 + x I_0 \exp\left(-\frac{d_A}{L_{TH} \cos\theta} \right), $$

# %% [markdown]
# $$ x = \frac{I_f/I_0 - 1}{  \exp\left(-\frac{ d_{ML} }{ L_{TH} \cos\theta }\right) - 1  } $$

# %%
path = '/Users/pabloherrero/sabat/xps_spectra/ITO_FBI/qITO_subl/**/*.uxy'

files = glob.glob(path, recursive=True)
files.sort()

files
# Out:
# ['/Users/pabloherrero/sabat/xps_spectra/ITO_FBI/qITO_subl/2021_04_15_qITO/proc/20210415_1-qITO_FBI_subl_60min.uxy',
#  '/Users/pabloherrero/sabat/xps_spectra/ITO_FBI/qITO_subl/2021_04_15_qITO/proc/20210415_1-qITO_as_received.uxy',
#  '/Users/pabloherrero/sabat/xps_spectra/ITO_FBI/qITO_subl/2021_04_15_qITO/proc/20210415_1-qITO_clean.uxy']

# %%
bg_exps = [read_processed_xp(f) for f in files]

# %%
from invisible_cities.core.system_of_units import nm

inds = [[0, 1, 2]]

layers_fbi = arrange_coverages(bg_exps, inds,
                               r_ml = 1.1*nm, region='In3d', mfp = 3.05*nm, takeoff = 10)

# %%
layers_fbi[:,1]
# Out:
# matrix([[0.01434568],
#         [0.01549277]])

# %%
bg_exps[0].area
# Out:
# {'C1s': 10638.944122492523,
#  'N1s': 1360.117001036402,
#  'O1s': 14685.780718686012,
#  'Si2p': 1366.1142485721916,
#  'In3d': 13640.39386076357,
#  'Sn3d': 1471.6591952835993}

# %%
tsubl
# Out:
# ['1-qITO_as_received', '1-qITO_clean']

# %%
tsubl = [xp.name for xp in bg_exps[1:]]

plt.errorbar(x=tsubl, y=layers_fbi[:,0], yerr=layers_fbi[:,1], fmt='o', label='Rate $R_0$')

plt.ylabel('Layers')
plt.xlabel('FBI Evap. time [min]')
plt.legend()
# plt.gcf().savefig('/Users/pabloherrero/Dropbox/phd/papers/fbi_cu_sublim_v2/FBI_thickness.png', dpi=200)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-55f68dde296b> in <module>
#       1 tsubl = [xp.name for xp in bg_exps[1:]]
#       2
# ----> 3 plt.errorbar(x=tsubl, y=layers_fbi[:,0], yerr=layers_fbi[:,1], fmt='o', label='Rate $R_0$')
#       4
#       5 plt.ylabel('Layers')
#
# ~/anaconda3/envs/IC-3.7-2018-11-14/lib/python3.7/site-packages/matplotlib/pyplot.py in errorbar(x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, data, **kwargs)
#    2577         lolims=lolims, uplims=uplims, xlolims=xlolims,
#    2578         xuplims=xuplims, errorevery=errorevery, capthick=capthick,
# -> 2579         **({"data": data} if data is not None else {}), **kwargs)
#    2580
#    2581
#
# ~/anaconda3/envs/IC-3.7-2018-11-14/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1803                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1804                         RuntimeWarning, stacklevel=2)
# -> 1805             return func(ax, *args, **kwargs)
#    1806
#    1807         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/envs/IC-3.7-2018-11-14/lib/python3.7/site-packages/matplotlib/axes/_axes.py in errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3243
#    3244         if yerr is not None:
# -> 3245             lower, upper = extract_err(yerr, y)
#    3246             # select points without upper/lower limits in y and
#    3247             # draw normal errorbars for these points
#
# ~/anaconda3/envs/IC-3.7-2018-11-14/lib/python3.7/site-packages/matplotlib/axes/_axes.py in extract_err(err, data)
#    3173                     # using list comps rather than arrays to preserve units
#    3174                     low = [thisx - thiserr for thisx, thiserr
# -> 3175                            in cbook.safezip(data, a)]
#    3176                     high = [thisx + thiserr for thisx, thiserr
#    3177                             in cbook.safezip(data, b)]
#
# ~/anaconda3/envs/IC-3.7-2018-11-14/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in safezip(*args)
#     777     for i, arg in enumerate(args[1:]):
#     778         if len(arg) != Nx:
# --> 779             raise ValueError(_safezip_msg % (Nx, i + 1, len(arg)))
#     780     return list(zip(*args))
#     781
#
# ValueError: In safezip, len(args[0])=2 but len(args[1])=1

# %% [markdown]
# ### Estimate $R_0$

# %%
r0 = []
for i, th in enumerate(thickmf[:,0]):
    r0.append(th/nm/tsubl[i])
    
np.average(r0), np.std(r0) # in nm/min
# Out:
# (0.021917619832435533, 0.004914634810493144)

# %% [markdown]
# ### Estimate R1 = 4.3·R$_0$

# %%
np.average(rate_ratios[:,0,0]) * np.average(r0), np.average(rate_ratios[:,0,0]) * np.std(r0),
# Out:
# (0.09454170270840903, 0.021199288368275775)

# %%
for i, th in enumerate(thickmfcal[:,0]):
    print(th/nm/tsubl_calib[i])
# Out:
# [[0.02565079]]
# [[0.09650838]]
# [[0.04286278]]

# %% [markdown]
# # Check expected attenuation in O, N and C 1s from BaCl2 deposition

# %% [markdown]
# ## Plot progba set

# %%
plt.rcParams['lines.linewidth'] = 2.5

# %%
compress_noisy_region(bg_exps[10], bg_exps[6], 'N_1s', inplace=True);

# %%
bg_exps[6].color = 'g'
bg_exps[7].color = 'b'
bg_exps[10].color = 'y'

# %%
ax = plot_xp_regions(bg_exps[6:8]+[bg_exps[10]], regions=['Cu_2p', 'O_1s', 'N_1s', 'C_1s'], ncols=2)
# ax[0][0].set(ylim=(0, ax[0][0].get_ylim()[1]*0.65))
ax[0][0].legend()

# %%
ax = plot_xp_regions(bg_exps[6:11], regions=['Cu_2p', 'O_1s', 'N_1s', 'C_1s'], ncols=2)
ax[0][0].set(ylim=(0, ax[0][0].get_ylim()[1]*0.65))
ax[0][0].legend()

# %% [markdown]
# ## Thickness from Cu 2p attenuation
# EAL for Cu 2p through BaCl$_2$ = 1.36 nm

# %% [markdown]
# For a system with a substrate and two independent overlayers (I: interlayer, T: top layer), we expect the attenuation of substrate (Cu 2p) core level intensity to be:
# $$ I_f = I_0 \exp\left(-\frac{d_I }{ L_I  \cos\theta} \right) \exp\left(-\frac{d_T }{ L_T  \cos\theta} \right) = $$
# $$ I_f = I_I \exp\left(-\frac{d_T }{ L_T  \cos\theta} \right), $$
# where $I_I = I_0 \exp\left(-\frac{d_I}{L_I \cos\theta} \right),$ is the intensity of the Cu 2p CL measured with interlayer (FBI) attenuation.

# %%
(dI LT + dT LI) / LI LT costh

# %%
progba = []
thickFBI60 = layer_thickness(xpf=bg_exps[6], xp0=bg_exps[10], region='Cu_2p', mfp=1.86*nm, takeoff=10)
progba.append(layer_thickness(xpf=bg_exps[7], xp0=bg_exps[6], region='Cu_2p', mfp=1.36*nm, takeoff = 10))
progba.append(layer_thickness(xpf=bg_exps[8], xp0=bg_exps[6], region='Cu_2p', mfp=1.36*nm, takeoff = 10))
progba.append(layer_thickness(xpf=bg_exps[9], xp0=bg_exps[6], region='Cu_2p', mfp=1.36*nm, takeoff = 10))

progba
# Out:
# [(2.470515463624076e-07, 3.940742070916728e-09),
#  (3.452528325520955e-07, 4.021750923585e-09),
#  (3.954749044619526e-07, 4.06486156055328e-09)]

# %% [markdown]
# ## Compute attenuation factor for O 1s:
#
# $$ \frac{I_f}{I_0} = \exp\left(-\frac{d_{BaCl_2}}{\lambda_{O1s} \cos\theta} \right) $$

# %% [markdown]
# ### IMFP for O 1s through BaCl$_2$
# $\lambda_{in} $ = 22.04 Å

# %%
BE_N = 534 # eV
hv = 1486.6
KE_N = hv - BE_N
KE_N
# Out:
# 952.5999999999999

# %%
imfp = 2.20 * nm

attFact = []
costh = np.cos(takeoff*np.pi/180)
for thick in progba:
    attFact.append(np.exp(-thick[0]/imfp*costh))

attFact
# Out:
# [0.8953056358096017, 0.8568015599305181, 0.8377543651330644]

# %%
trim_spectra(bg_exps[10], xpRef=bg_exps[7], region=region, inplace=True);

# %%
region = 'O_1s'
xp0 = bg_exps[6]
x = xp0.dfx[region].dropna().energy
y0 = xp0.dfx[region].dropna().counts

fig, ax = plt.subplots(3, sharex=True, figsize=(10, 12))

for i, xp in enumerate(bg_exps[7:10]):
    y = xp.dfx[region].dropna().counts
    yexp = y0*attFact[i]
    
    ax[i].plot(x, y, label='Measurement')
    ax[i].plot(x, y0, label='Reference FBI layer')
    ax[i].plot(x, yexp, label='Expected attenuation')  
    ax[i].set(yticks=[], title=xp.name.replace('Cu_FBI_subl_60min_', ''))
    ax[i].invert_xaxis()
ax[0].legend()

# %% [markdown]
# ## Compute attenuation factor for N 1s:
#
# $$ \frac{I_f}{I_0} = \exp\left(-\frac{d_{BaCl_2}}{\lambda_{N1s} \cos\theta} \right) $$

# %% [markdown]
# ### IMFP for N 1s through BaCl$_2$
# $\lambda_{in} $ = 24.40 Å

# %%
BE_N = 400 # eV
hv = 1486.6
KE_N = hv - BE_N
KE_N
# Out:
# 1086.6

# %%
imfp = 2.44 * nm

attFact = []
costh = np.cos(takeoff*np.pi/180)
for thick in progba:
    attFact.append(np.exp(-thick[0]/imfp*costh))

attFact
# Out:
# [0.9050976784482725, 0.8699257600943503, 0.8524697781304917]

# %%
region = 'N_1s'
xp0 = bg_exps[6]
x = xp0.dfx[region].dropna().energy
y0 = xp0.dfx[region].dropna().counts

fig, ax = plt.subplots(3, sharex=True, figsize=(10, 12))

for i, xp in enumerate(bg_exps[7:10]):
    y = xp.dfx[region].dropna().counts
    yexp = y0*attFact[i]
    
    ax[i].plot(x, y, label='Measurement')
    ax[i].plot(x, y0, label='Reference FBI layer')
    ax[i].plot(x, yexp, label='Expected attenuation')  
    ax[i].set(yticks=[], title=xp.name.replace('Cu_FBI_subl_60min_', ''))
    ax[i].invert_xaxis()
ax[0].legend()

# %% [markdown]
# ## Compute attenuation factor for C 1s:
#
# $$ \frac{I_f}{I_0} = \exp\left(-\frac{d_{BaCl_2}}{\lambda_{C1s} \cos\theta} \right) $$

# %% [markdown]
# ### IMFP for C 1s through BaCl$_2$
# $\lambda_{in} $ = 24.40 Å

# %%
BE_N = 286 # eV
hv = 1486.6
KE_N = hv - BE_N
KE_N
# Out:
# 1200.6

# %%
imfp = 2.63 * nm

attFact = []
costh = np.cos(takeoff*np.pi/180)
for thick in progba:
    attFact.append(np.exp(-thick[0]/imfp*costh))

attFact
# Out:
# [0.9116411419509397, 0.8787274642132523, 0.8623567614891514]

# %%
region = 'C_1s'
xp0 = bg_exps[6]
x = xp0.dfx[region].dropna().energy
y0 = xp0.dfx[region].dropna().counts

fig, ax = plt.subplots(3, sharex=True, figsize=(10, 12))

for i, xp in enumerate(bg_exps[7:10]):
    y = xp.dfx[region].dropna().counts
    yexp = y0*attFact[i]
    
    ax[i].plot(x, y, label='Measurement')
    ax[i].plot(x, y0, label='Reference FBI layer')
    ax[i].plot(x, yexp, label='Expected attenuation')  
    ax[i].set(yticks=[], title=xp.name.replace('Cu_FBI_subl_60min_', ''))
    ax[i].invert_xaxis()
ax[0].legend()
