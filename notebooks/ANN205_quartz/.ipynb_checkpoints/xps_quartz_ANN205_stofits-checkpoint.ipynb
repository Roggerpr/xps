# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import glob
import os
import peakutils
import logging
import datetime
import warnings
from lmfit.models import PseudoVoigtModel, GaussianModel
from jupyterthemes import jtplot
from matplotlib.colors import Normalize

# %%
from xps.xps_sw import *
from xps.xps_import import *
from xps.xps_analysis import *
from xps.xps_bg import *
from xps.xps_fits import *

jtplot.style('grade3', context='talk', grid=False, ticks=True, fscale=1.5)
logging.getLogger().setLevel(logging.CRITICAL)
warnings.filterwarnings("ignore")

# %%
asf = dict({'C1s' : 0.296, 'O1s' : 0.711, 'O1s_sub' : 0.711, 'N1s' : 0.477, 'Ba3d' : 7.49, 'Ba_3d_5/2' : 7.49, 'Ba_3d_3/2' : 5.20,
            'Br_3p' : 1.054, 'Cu_2p' : 5.321, 'Ba_4d': 2.35, 'Na1s' : 1.685, 'Cl_2s' : 0.37, 'Ru3d' : 4.273, 'Ru3p' : 1.53,
           'In3d' : 4.359, 'Sn3d' : 4.725, 'Cl2p' : 0.891, 'Cl2p_(2)' : 0.891, 'Cl2p_(3)' : 0.891, 'Si2p': 0.339})

asf2 = {'Ba_3d_5/2' : 25.8, 'Ba_3d_3/2': 17.9, 'Ba_4d': 5.86, 'Cl_2p': 2.28, 'Cl_2s': 1.69, }

asf3 = {'Ba_3d_5/2' : 64.3, 'Ba_3d_3/2': 49.9, 'Ba_4d': 5.86, 'Cl_2p': 2.28, 'Cl_2s': 1.50}
mfps = {'Cu2p' : 1.86, 'In3d': 3.05, 'Si2p': 3.8}

# %%
regss = ['O1s', 'Si2p', 'N1s', 'C1s', 'In3d', 'Ba3d5/2', 'Cl2p', 'Ru3d5/2', 'Si2s', 'Ru3p3/2', 'Ir4d5/2']
asfScof = {}
for r in regss:
    asfScof.update(search_asf(r))

# %%
asfScof
# Out:
# {'O1s': 0.6613995485327314,
#  'Si2p': 0.18442437923250563,
#  'N1s': 0.4063205417607223,
#  'C1s': 0.2257336343115124,
#  'In3d': 5.088036117381489,
#  'Ba3d5/2': 5.832957110609481,
#  'Cl2p': 0.5158013544018059,
#  'Ru3d5/2': 1.6681715575620766,
#  'Si2s': 0.21557562076749434,
#  'Ru3p3/2': 1.530474040632054}

# %% [markdown]
# # Preprocess data

# %%
path = '/Users/pabloherrero/sabat/xps_spectra/quartz_ANN205/'
files = glob.glob(path+'*.xy')
# files += glob.glob(path+'*.xy')
files.sort()
files
# Out:
# ['/Users/pabloherrero/sabat/xps_spectra/quartz_ANN205/20220525_quartz_ANN205_silatrane_5e-5M_AcN.xy',
#  '/Users/pabloherrero/sabat/xps_spectra/quartz_ANN205/20220526_quartz_ANN205_silatrane_5e-5M_AcN_BaCl2_30s.xy']

# %%
group = import_group_xp(files[0])
group[1]
# Out:
# XPS_experiment(path='/Users/pabloherrero/sabat/xps_spectra/quartz_ANN205/20220525_quartz_ANN205_silatrane_5e-5M_AcN.xy', delimiters=([3836], [6021], ['overview']), name='Spectrum Group (2)', label=None, date=None, other_meta=None, dfx=range      overview
# properties   energy   counts
# 0            1200.0  3658.75
# 1            1199.8  3587.75
# 2            1199.6  3579.50
# 3            1199.4  3650.50
# 4            1199.2  3595.00
# ...             ...      ...
# 6016           -3.2   237.00
# 6017           -3.4   214.75
# 6018           -3.6   235.75
# 6019           -3.8   225.25
# 6020           -4.0   221.00
#
# [6021 rows x 2 columns], area=None, fit=None, color=None, ls=None)

# %%
experiments = [xps_data_import(f) for f in files]
experiments[0].name
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-113e89be9843> in <module>
# ----> 1 experiments = [xps_data_import(f) for f in files]
#       2 experiments[0].name
#
# <ipython-input-9-113e89be9843> in <listcomp>(.0)
# ----> 1 experiments = [xps_data_import(f) for f in files]
#       2 experiments[0].name
#
# ~/sabat/sabatsw/xps/xps_import.py in xps_data_import(path, name, label, color)
#     215     dfx = import_single_df(path, skipRows0, nrows0, regions)
#     216
# --> 217     if check_arrays(dfx[delimiters[2][0]]):
#     218         hv = excitation_energy_metadata(path, delimiters[2][0])
#     219         dfx = ke_to_be(dfx, hv)
#
# ~/sabat/sabatsw/xps/xps_import.py in check_arrays(dfr)
#     147     x, y = dfr.dropna().energy.values, dfr.dropna().counts.values
#     148     # Next ensure the energy values are *decreasing* in the array,
# --> 149     if x[0] < x[-1]:
#     150         is_reversed = True
#     151         return is_reversed
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
for xp in experiments[1:-1]:
    shift = find_shift(xp, experiments[0], region='Si2p')
    align_dfx(xp, shift, inplace=True);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/IC-3.7-2018-11-14/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Si2p'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-ba47b228c911> in <module>
#       1 for xp in experiments[1:-1]:
# ----> 2     shift = find_shift(xp, experiments[0], region='Si2p')
#       3     align_dfx(xp, shift, inplace=True);
#
# ~/sabat/sabatsw/xps/xps_bg.py in find_shift(xp, xpRef, region)
#      25 def find_shift(xp : XPS_experiment, xpRef : XPS_experiment, region : str) -> float:
#      26     """Compare maxima between two spectra and get energy shift"""
# ---> 27     x = xp.dfx[region].dropna().energy
#      28     y = xp.dfx[region].dropna().counts.values
#      29     xRef = xpRef.dfx[region].dropna().energy
#
# ~/anaconda3/envs/IC-3.7-2018-11-14/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3021         if is_single_key:
#    3022             if self.columns.nlevels > 1:
# -> 3023                 return self._getitem_multilevel(key)
#    3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#
# ~/anaconda3/envs/IC-3.7-2018-11-14/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    3072     def _getitem_multilevel(self, key):
#    3073         # self.columns is a MultiIndex
# -> 3074         loc = self.columns.get_loc(key)
#    3075         if isinstance(loc, (slice, np.ndarray)):
#    3076             new_columns = self.columns[loc]
#
# ~/anaconda3/envs/IC-3.7-2018-11-14/lib/python3.7/site-packages/pandas/core/indexes/multi.py in get_loc(self, key, method)
#    2874
#    2875         if not isinstance(key, tuple):
# -> 2876             loc = self._get_level_indexer(key, level=0)
#    2877             return _maybe_to_slice(loc)
#    2878
#
# ~/anaconda3/envs/IC-3.7-2018-11-14/lib/python3.7/site-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    3156         else:
#    3157
# -> 3158             idx = self._get_loc_single_level_index(level_index, key)
#    3159
#    3160             if level > 0 or self.lexsort_depth == 0:
#
# ~/anaconda3/envs/IC-3.7-2018-11-14/lib/python3.7/site-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2807             return -1
#    2808         else:
# -> 2809             return level_index.get_loc(key)
#    2810
#    2811     def get_loc(self, key, method=None):
#
# ~/anaconda3/envs/IC-3.7-2018-11-14/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Si2p'

# %%
regions = ['O1s', 'N1s', 'C1s', 'Ba3d', 'Cl2p', 'Si2p']
bg = bulk_bg_subtract(experiments, regions);

# %%
bg[5] = subtract_als_bg(bg[5], 'Na1s', )

# %%
bg[5] = subtract_shirley_bg(bg[5], 'Ru3p', maxit=70)

# %%
plot_xp_regions(bg, regions, ncols=3);

# %%
scaled = scale_and_plot_spectra(bg, indRef=0, region='Si2p')

# %%
plot_xp_regions(scaled, regions, ncols=3);

# %%
norm = []
for xp in scaled[1:]:
    norm.append(normalise_dfx(xp))
compress_noisy_region(norm[0], norm[1], 'Ba3d', inplace=True, flag_plot=False);
compress_noisy_region(norm[0], norm[1], 'Cl2p', inplace=True, flag_plot=False);

# %%
norm[0].color = 'r'
norm[0].name = 'G2-SL/quartz'
norm[1].color = 'g'
norm[1].name = 'BaCl$_2$/G2-SL/quartz'

regions = ['C1s', 'N1s', 'Si2p', 'Ba3d', 'Cl2p', 'O1s']

plot_xp_regions(norm, regions, ncols=3);

# %%
def store_results(bg_exps: list, scaled_exps: list):

    for xpu, xps in zip(bg_exps, scaled_exps):
        filepath, filename = os.path.split(xpu.path)
        filename = os.path.splitext(filename)[0]
        newpath = filepath + '/proc/'
        try:
            os.mkdir(newpath)
        except FileExistsError: pass
        print('Stored ', newpath + filename)
        write_processed_xp(newpath + filename + '.uxy', xpu)
        write_processed_xp(newpath + filename + '.sxy', xps)

# %%
store_results(bg, scaled)

# %% [markdown]
# ## Fit C 1s

# %%
xp = bg[1]
xp.color = 'r'
region = 'C1s'
scale = 1

fit_n_voigt(xp, region, max_comps=4, flag_save=True)

# %%
xp = bg[2]
xp.color = 'g'

region = 'C1s'
scale = 1

fit_n_voigt(xp, region, max_comps=4, flag_save=True)

# %%
plot_fit_result(bg[1], region, fitRes=bg[1].fit['C1s_4comps'])
plot_fit_result(bg[2], region, fitRes=bg[2].fit['C1s_4comps'], offset=9)
plt.gca().set(xlim=(296.5,285), ylim=(0, 2e3))

# %% [markdown]
# ## Subtract O 1s

# %%
def clean_reg_subtract(exps: list, xpRef: XPS_experiment, region: str):
    """
        Subtract clean substrate contribution in region to whole set of exps.
        Store result in new dfx region as region+'_sub'
        input
        ------------
        exps: list of experiments to perform operation onto
        xpRef: XPS_experiment with clean region
        region: str
    """
    fig, ax = plt.subplots(len(exps), figsize=(6, 6*len(exps)))
    for i, xp in enumerate(exps):
        subexps = subtract_ref_region(xp, xpRef, region=region, )
        plot_region(xp, region, ax=ax[i])
        subexps.ls = '--'
        plot_region(subexps, region, ax=ax[i])
        plot_region(xpRef, region, ax=ax[i])
        ax[i].invert_xaxis()
        ax[i].legend()
        
        xp.dfx[region+'_sub', 'energy'] = subexps.dfx[region].energy
        xp.dfx[region+'_sub', 'counts'] = subexps.dfx[region].counts
    return exps

# %%
clean_reg_subtract(scaled[1:], scaled[0], region='O1s')

# %% [markdown]
# # Stoichiometry

# %%
path = '/Users/pabloherrero/sabat/xps_spectra/quartz_FBIG2/*G2SL*/proc/'
files = glob.glob(path+'*.uxy')
# files += glob.glob(path+'*.xy')
files.sort()
# files.pop(5)
files
# Out:
# ['/Users/pabloherrero/sabat/xps_spectra/quartz_FBIG2/2022_04_07_quartz_G2SL_BOLD073_A1/proc/20211220_Quartz_clean.uxy',
#  '/Users/pabloherrero/sabat/xps_spectra/quartz_FBIG2/2022_04_07_quartz_G2SL_BOLD073_A1/proc/20220407_quartz_FBIG2_silatrane_BOLD073A1.uxy',
#  '/Users/pabloherrero/sabat/xps_spectra/quartz_FBIG2/2022_04_07_quartz_G2SL_BOLD073_A1/proc/20220407_quartz_FBIG2_silatrane_BOLD073A1_BaCl2_2min.uxy',
#  '/Users/pabloherrero/sabat/xps_spectra/quartz_FBIG2/2022_04_21_quartz_G2SL_BOLD073_A2/proc/20220420_quartz_FBIG2_silatrane_BOLD073A2.uxy',
#  '/Users/pabloherrero/sabat/xps_spectra/quartz_FBIG2/2022_04_21_quartz_G2SL_BOLD073_A2/proc/20220420_quartz_FBIG2_silatrane_BOLD073A2_BaCl2_15sec.uxy',
#  '/Users/pabloherrero/sabat/xps_spectra/quartz_FBIG2/2022_04_26_quartz_G2SL_BOLD078_A2/proc/20220427_quartz_FBIG2_silatrane_BOLD078A2_BaCl2_15s.uxy',
#  '/Users/pabloherrero/sabat/xps_spectra/quartz_FBIG2/2022_05_20_quartz_G2SL_BOLD078_C1/proc/20220520_quartz_FBIG2_silatrane_BOLD078C1_BaCl2_15s.uxy']

# %%
bg = [read_processed_xp(f) for f in files]
# Out:
# [Errno 2] No such file or directory: '/Users/pabloherrero/sabat/xps_spectra/quartz_FBIG2/2022_04_07_quartz_G2SL_BOLD073_A1/proc/20211220_Quartz_clean.uxy.ft', returning empty fit dict
# [Errno 2] No such file or directory: '/Users/pabloherrero/sabat/xps_spectra/quartz_FBIG2/2022_04_07_quartz_G2SL_BOLD073_A1/proc/20220407_quartz_FBIG2_silatrane_BOLD073A1.uxy.ft', returning empty fit dict
# [Errno 2] No such file or directory: '/Users/pabloherrero/sabat/xps_spectra/quartz_FBIG2/2022_04_07_quartz_G2SL_BOLD073_A1/proc/20220407_quartz_FBIG2_silatrane_BOLD073A1_BaCl2_2min.uxy.ft', returning empty fit dict
# [Errno 2] No such file or directory: '/Users/pabloherrero/sabat/xps_spectra/quartz_FBIG2/2022_04_21_quartz_G2SL_BOLD073_A2/proc/20220420_quartz_FBIG2_silatrane_BOLD073A2.uxy.ft', returning empty fit dict
# [Errno 2] No such file or directory: '/Users/pabloherrero/sabat/xps_spectra/quartz_FBIG2/2022_04_21_quartz_G2SL_BOLD073_A2/proc/20220420_quartz_FBIG2_silatrane_BOLD073A2_BaCl2_15sec.uxy.ft', returning empty fit dict
# [Errno 2] No such file or directory: '/Users/pabloherrero/sabat/xps_spectra/quartz_FBIG2/2022_04_26_quartz_G2SL_BOLD078_A2/proc/20220427_quartz_FBIG2_silatrane_BOLD078A2_BaCl2_15s.uxy.ft', returning empty fit dict
# [Errno 2] No such file or directory: '/Users/pabloherrero/sabat/xps_spectra/quartz_FBIG2/2022_05_20_quartz_G2SL_BOLD078_C1/proc/20220520_quartz_FBIG2_silatrane_BOLD078C1_BaCl2_15s.uxy.ft', returning empty fit dict

# %%
plot_xp_regions(bg[5:], regs+['Na1s'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcba8e73240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcb58034358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcb58058898>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcb79468e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcb7a1f93c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcb7a222940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcb7a36beb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcb89412438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcb898d4898>]],
#       dtype=object)

# %%
for xp in bg:
    xp.area = {}

# %%
regs = ['O1s', 'Si2p', 'N1s', 'C1s', 'Ba3d', 'Cl2p']

for r in regs:
    integrateRegions(bg, r, asf=asf)
# Out:
# 'Ba3d' region does not exist in Quartz_clean
# 'Cl2p' region does not exist in Quartz_clean

# %%
bg[5] = subtract_als_bg(bg[5], 'Na1s')

# %%
regions = list(bg[0].dfx.columns.levels[0])
for i,r in enumerate(regions):
    if '_bg' in r:
        regions.pop(i)

# %%
regions
# Out:
# ['C1s',
#  'C1s_bg',
#  'N1s',
#  'N1s_bg',
#  'O1s',
#  'O1s_bg',
#  'Si2p',
#  'Si2p_bg',
#  'overview']

# %%
regions
# Out:
# ['C1s', 'N1s', 'O1s', 'Si2p', 'overview']

# %%
regs = ['Na1s', 'Ru3p']

for r in regs:
    integrateRegions([bg[5], bg[6]], r, asf=asf)

# %%
a = {'C1s': 12+6+6+5+2+1+3, 'N1s': 4, 'Si2p': 1, 'O1s': 9, 'Ba3d': 1e-10, 'Cl2p': 1e-10, 'G2': 1, 'Na1s': 1e-10, 'Ru3p': 1e-10}
g2sl = XPS_experiment(name='Sto. G2-SL', area=a)

for xp in bg[1:]:
    xp.area['G2'] = xp.area['N1s'] / 4

# %%
num = ['C1s', 'Ba3d', 'Ba3d']
denom = ['N1s', 'Cl2p', 'G2']
display_stoichiometry(bg[1:]+[g2sl], num, denom)
# Out:
# <table><tr><td><h4>Experiment</h4><td><td><h4>C/N</h4><td><td><h4>Ba/Cl</h4><td><td><h4>Ba/G</h4><td></tr><tr><td><h4>quartz_FBIG2_silatrane_BOLD073A1</h4><td><td><h4>11.20</h4><td><td><h4>0.50</h4><td><td><h4>0.59</h4><td></tr><tr><td><h4>quartz_FBIG2_silatrane_BOLD073A1_BaCl2_2min</h4><td><td><h4>11.66</h4><td><td><h4>1.19</h4><td><td><h4>34.63</h4><td></tr><tr><td><h4>quartz_FBIG2_silatrane_BOLD073A2</h4><td><td><h4>11.26</h4><td><td><h4>0.23</h4><td><td><h4>0.36</h4><td></tr><tr><td><h4>quartz_FBIG2_silatrane_BOLD073A2_BaCl2_15sec</h4><td><td><h4>10.03</h4><td><td><h4>1.23</h4><td><td><h4>3.68</h4><td></tr><tr><td><h4>quartz_FBIG2_silatrane_BOLD078A2_BaCl2_15s</h4><td><td><h4>8.12</h4><td><td><h4>0.72</h4><td><td><h4>1.53</h4><td></tr><tr><td><h4>quartz_FBIG2_silatrane_BOLD078C1_BaCl2_15s</h4><td><td><h4>9.66</h4><td><td><h4>1.30</h4><td><td><h4>7.21</h4><td></tr><tr><td><h4>Sto. G2-SL</h4><td><td><h4>8.75</h4><td><td><h4>1.00</h4><td><td><h4>0.00</h4><td></tr></table>

# %%
num = ['Ba3d', 'Na1s', 'Ru3p']
denom = ['G2', 'G2', 'G2']
display_stoichiometry(bg[5:]+[g2sl], num, denom)
# Out:
# <table><tr><td><h4>Experiment</h4><td><td><h4>Ba/G</h4><td><td><h4>Na/G</h4><td><td><h4>Ru/G</h4><td></tr><tr><td><h4>quartz_FBIG2_silatrane_BOLD078A2_BaCl2_15s</h4><td><td><h4>1.53</h4><td><td><h4>1.86</h4><td><td><h4>68.02</h4><td></tr><tr><td><h4>quartz_FBIG2_silatrane_BOLD078C1_BaCl2_15s</h4><td><td><h4>7.21</h4><td><td><h4>9.68</h4><td><td><h4>5.98</h4><td></tr><tr><td><h4>Sto. G2-SL</h4><td><td><h4>0.00</h4><td><td><h4>0.00</h4><td><td><h4>0.00</h4><td></tr></table>

# %%
num = ['C1s', 'Ba3d', 'Na1s']
denom = ['N1s', 'G2', 'G2']
make_stoichometry_table(bg[5:]+[g2sl], num, denom)
# Out:
# Experiment	C/N	Ba/G	Na/G
# quartz_FBIG2_silatrane_BOLD078A2_BaCl2_15s	8.12 	 1.53 	 1.86
# quartz_FBIG2_silatrane_BOLD078C1_BaCl2_15s	9.66 	 7.21 	 9.68
# Sto. G2-SL	8.75 	 0.00 	 0.00

# %% [markdown]
# # Main plots...

# %%
region = 'Ba3d'
for xp in bg[3:]:
    plot_region(xp, region, lb = xp.name.replace('quartz_FBIG2_silatrane_', '').replace('_15sec', '').replace('_15s', ''))
    
plt.gca().invert_xaxis()
plt.legend(fontsize=22, loc='best')

# %%
region = 'C1s'
for xp in norm[:2]:
    plot_region(xp, region, lb = xp.name.replace('quartz_FBIG2_silatrane_', ''))
    
plt.gca().set(xlim=(297.5, 281))
plt.legend(fontsize=22, loc='best')

# %%
region = 'C1s'
cols = ['r', 'm']
for i,xp in enumerate(norm[2:4]):
    xp.color = cols[i]
    plot_region(xp, region, lb = xp.name.replace('quartz_FBIG2_silatrane_', ''))
    
plt.gca().set(xlim=(297.5, 285))
plt.legend(fontsize=22, loc='best')

# %%
region = 'C1s'
cols = ['r', 'm', 'y']
for i,xp in enumerate(norm[2:]):
    xp.color = cols[i]
    plot_region(xp, region, lb = xp.name.replace('quartz_FBIG2_silatrane_', ''))
    
# plt.gca().set(xlim=(297.5, 285))
plt.legend(fontsize=22, loc='best')

# %% [markdown]
# ## Other regions

# %%
plot_region(bg[5], 'Na1s')
plt.gca().get_legend().remove()

# %%
plot_region(bg[5], 'Ru3p')
plt.gca().get_legend().remove()

# %%
fileovw = '/Users/pabloherrero/sabat/xps_spectra/quartz_FBIG2/2022_04_26_quartz_G2SL_BOLD078_A2/20220426_quartz_FBIG2_silatrane_BOLD078A2.xy'

ovw = xps_data_import(fileovw)

# %%
fileru = '/Users/pabloherrero/sabat/xps_spectra/ITO_Ru-Ir/2022_02_03_qITO_RuPTES_BOLD038A/20220203_qITO_PTES_Ru.xy'

ru = xps_data_import(fileru)
align_dfx(ru, shift=1.4, inplace=True)

# %%
plt.rcParams['lines.linewidth'] = 1

plt.figure(figsize=(16, 8))
plot_region(ovw, 'overview')
plt.rcParams['lines.linewidth'] = 2.08

# %%
plt.rcParams['lines.linewidth'] = 1

plt.figure(figsize=(8, 8))
plot_region(ovw, 'overview')
plt.gca().set(xlim=(1080, 1070), ylim=(3e3, 3.6e3))
plt.rcParams['lines.linewidth'] = 2.08

# %%
plt.rcParams['lines.linewidth'] = 1

plt.figure(figsize=(8, 8))
plot_region(ovw, 'overview', offset=300)
plot_region(ru, 'C1s')

plt.gca().set(xlim=(294, 272), ylim=(0.9e3, 2.2e3))
plt.rcParams['lines.linewidth'] = 2.08

# %%
plt.rcParams['lines.linewidth'] = 1

plt.figure(figsize=(12, 8))
plot_region(ovw, 'overview')
# plot_region(experiments[5], 'N1s')

plt.gca().set(xlim=(507, 396), ylim=(0.7e3, 1e3))
plt.rcParams['lines.linewidth'] = 2.08
