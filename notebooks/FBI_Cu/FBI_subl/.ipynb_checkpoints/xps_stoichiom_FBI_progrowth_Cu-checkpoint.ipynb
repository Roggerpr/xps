# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import glob
import os
import peakutils
import datetime
import warnings
from jupyterthemes import jtplot

import logging

# %%
logging.getLogger().setLevel(logging.CRITICAL)

from xps.xps_sw import *
from xps.xps_import import *
from xps.xps_analysis import *
from xps.xps_bg import *

# %%
jtplot.style('default', grid=False)
plt.rcParams['errorbar.capsize'] = 8
plt.rcParams['font.size'] = 18
plt.rc('font', size= 18)
plt.rc('legend', fontsize= 15)
plt.rc('xtick', labelsize= 18)
plt.rc('ytick', labelsize= 18)
plt.rc('axes', labelsize=18)
plt.rc('axes', titlesize=18)

# %%
asf = dict({'C_1s' : 0.296, 'O_1s' : 0.711, 'N_1s' : 0.477, 'Ba_3d' : 7.49,
            'Cu_2p' : 5.321, 'Cl_2p' : 0.891})

# %%
Na = 6.023e23
M = 529
R = 7.33e-8 # cm
rho = M/Na/(4*np.pi/3*R**3)
rho
# Out:
# 0.5324051841398443

# %%
V = 4*np.pi/3*R**3 #cm^3
V
# Out:
# 1.6496831299488353e-21

# %% [markdown]
# # Analysis experiments on Cu from september 2020

# %% [markdown]
# ## Read processed experiments

# %%
path = '/Users/pabloherrero/sabat/xps_spectra/FBI_Cu/FBI_subl/**/*.xy'

files = glob.glob(path, recursive=True)
files.sort()
files_new = ['/Users/pabloherrero/sabat/xps_spectra/FBI_Cu/FBI_subl/2020_09_22_Cu/proc/20200922_1-Cu_clean.xy']

for f in files:
    if (' ' not in f) and ('/proc' in f) and ('BaCl'in f):
        files_new.append(f)
        
files = files_new
files
# Out:
# ['/Users/pabloherrero/sabat/xps_spectra/FBI_Cu/FBI_subl/2020_09_22_Cu/proc/20200922_1-Cu_clean.xy',
#  '/Users/pabloherrero/sabat/xps_spectra/FBI_Cu/FBI_subl/2020_09_22_Cu/proc/20200928_1-Cu_FBI_BaCl2_subl_20min.xy',
#  '/Users/pabloherrero/sabat/xps_spectra/FBI_Cu/FBI_subl/2020_10_19_Cu/proc/20201020_5-Cu_FBI_BaCl2_subl_10min.xy',
#  '/Users/pabloherrero/sabat/xps_spectra/FBI_Cu/FBI_subl/2020_10_21_Cu/proc/20201021_6-Cu_FBI_BaCl2_subl_20min.xy']

# %%
colors = ['k', 'b', 'r', 'y']
proc_exps = [read_processed_xp(f, ls='dashed') for f in files]
for xp, c in zip(proc_exps, colors):
    xp.color = c
    
proc_exps[0].ls = 'solid'

# %%
read_processed_xp(files[0], colors[0], ls='dashed').
# Out:
# '/Users/pabloherrero/sabat/xps_spectra/FBI_Cu/FBI_subl/2020_09_22_Cu/proc/20200922_1-Cu_clean.xy'

# %% [markdown]
# ## Show individual plots

# %%
regions = proc_exps[0].dfx.columns.levels[0].values
regions= ['N_1s', 'C_1s', 'O_1s', 'Ba_3d', 'Cl_2p', 'Cu_2p']

# %%
proc_exps[0].color, proc_exps[0].name
# Out:
# ('k', '1-Cu_clean')

# %%
plot_xp_regions(proc_exps, regions, ncols=3)
# plt.gcf().set_size_inches(20,10)
plt.gcf().savefig('/Users/pabloherrero/Dropbox/phd/papers/fbi_cu_sublimation/FBI_Ba_reproducibility2.png', dpi=200)

# %% [markdown]
# ### Normalized spectra

# %%
def plot_normal_regions(experiments : list, regions : list):
    """Subplots all normalized regions of a list of experiments"""
    rows = int(np.ceil(len(regions) / 3))
    cols = 3
    fig, ax = plt.subplots(rows, cols, figsize=(16, 8))
    for i,r in enumerate(regions):
        for xp in experiments:
            xp_norm = normalise_dfx(xp, inplace=False)
            j, k = i//3, i%3
            if i == len(experiments):   # Set labels from last region
                plot_region(xp_norm, r, ax=ax[j][k], lb=xp_norm.name)
                ax[j][k].set_title('Au_4f')
            else:
                plot_region(xp_norm, r, ax=ax[j][k], lb='__nolabel__')
                ax[j][k].set_title(r)
            cosmetics_plot(ax=ax[j][k], leg = False);
        if len(regions)%2 == 0:
            ax[j][k].invert_xaxis()
    plt.tight_layout()
    fig.legend()

# %%
plot_normal_regions(proc_exps[:2], regions)

# %% [markdown]
# ## Integrate areas

# %%
for xp in proc_exps:
    xp.area = {}

# %% [markdown]
# ### C 1s

# %%
region = 'C_1s'
integrateRegions(proc_exps, region, indRef=1, asf=asf)
# Out:
# [1639.5309340699632,
#  8102.5687658791585,
#  3387.2418434938977,
#  3363.2180706986705]

# %% [markdown]
# ### O 1s

# %%
region = 'O_1s'
integrateRegions(proc_exps, region, indRef=2, asf=asf)
# Out:
# [668.3983285336817, 4089.018103796835, 2658.7511415593062, 3030.335660517124]

# %% [markdown]
# #### Correct for bg substrate abundance

# %%
for xp in proc_exps[1:3]:
    uncorr_area = xp.area['O_1s']
    xp.area.update({'O_1s': uncorr_area - proc_exps[0].area['O_1s']})

# %%
[xp.area['O_1s'] for xp in proc_exps]
# Out:
# [940.082037318821, 4810.998277444661, 2799.3710450430726, 4262.075471894689]

# %% [markdown]
# ### N 1s

# %%
region = 'N_1s'
integrateRegions(proc_exps, region, indRef=1, asf=asf)
# Out:
# [27.9728420235381, 543.6316822193253, 303.1519972645437, 367.45163811326665]

# %% [markdown]
# ### Ba 3d

# %%
region = 'Ba_3d'
integrateRegions(proc_exps, region, indRef=1, asf=asf)
# Out:
# [10.339427798136764, 8313.790314050102, 5641.200477753713, 5479.191153405294]

# %% [markdown]
# ### Cl 2p

# %%
region = 'Cl_2p'
integrateRegions(proc_exps, region, indRef=2, asf=asf)
# Out:
# [176.63429245525242, 6244.7760739246, 1780.2068621447838, 2412.2230747661997]

# %%
xp.area
# Out:
# {'C_1s': 11443.384606398304,
#  'O_1s': 2799.3710450430726,
#  'N_1s': 628.8227129376892,
#  'Ba_3d': 753.164282744154,
#  'Cl_2p': 1997.9874996013286}

# %% [markdown]
# ### Cu 2p

# %%
region = 'Cu_2p'
integrateRegions(proc_exps, region, indRef=0, asf=asf)
# Out:
# [343335.33001777966, 360806.20267047547, 342446.39162056433, 360416.4927210023]

# %% [markdown]
# ## Stoichiometry

# %%
num, denom = (('N_1s', 'C_1s', 'C_1s', 'Ba_3d', 'O_1s', 'Cl_2p'), ('O_1s', 'N_1s', 'O_1s', 'N_1s', 'Cl_2p', 'Ba_3d'))
make_stoichometry_table(proc_exps,  num=num, denom=denom)
# Out:
# Experiment	N_/O_	C_/N_	C_/O_	Ba_/N_	O_/Cl_	Cl_/Ba_
# 1-Cu_clean	0.06	 94.45	 5.89	 0.02	 4.74	 143.61
# 1-FBI_BaCl2 20min	0.24	 24.02	 5.69	 0.97	 0.69	 6.31
# 5-FBI_BaCl2 10min	0.23	 18.01	 4.09	 1.19	 1.40	 2.65
# 6-FBI_BaCl2 20min	0.18	 14.75	 2.67	 0.95	 1.57	 3.70

# %%
print('Nominal')
print('N/O \t C/N \t \t C/O \t O/Cl (ClO4)')
print(3/5, '\t', '%.3f'%(31/3), '\t', '%.3f' %(31/5), '\t %.3f' %(4/1) )
# Out:
# Nominal
# N/O 	 C/N 	 	 C/O 	 O/Cl (ClO4)
# 0.6 	 10.333 	 6.200 	 4.000

# %%
ba2fbi = 3
1*5/(2*ba2fbi)
# Out:
# 0.8333333333333334
