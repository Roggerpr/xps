# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import glob
import os
import peakutils
import datetime
import warnings
from jupyterthemes import jtplot

import logging

# %%
logging.getLogger().setLevel(logging.CRITICAL)

from xps.xps_sw import *
from xps.xps_import import *
from xps.xps_analysis import *
from xps.xps_bg import *

# %%
jtplot.style('default', grid=False)
plt.rcParams['errorbar.capsize'] = 8
plt.rcParams['font.size'] = 18
plt.rc('font', size= 18)
plt.rc('legend', fontsize= 15)
plt.rc('xtick', labelsize= 18)
plt.rc('ytick', labelsize= 18)
plt.rc('axes', labelsize=18)
plt.rc('axes', titlesize=18)

# %%
asf = dict({'C_1s' : 0.296, 'O_1s' : 0.711, 'N_1s' : 0.477, 'Ba_3d' : 7.49,
            'Cu_2p' : 5.321, 'Cl_2p' : 0.891})

# %%
Na = 6.023e23
M = 529
R = 7.33e-8 # cm
rho = M/Na/(4*np.pi/3*R**3)
rho
# Out:
# 0.5324051841398443

# %%
V = 4*np.pi/3*R**3 #cm^3
V
# Out:
# 1.6496831299488353e-21

# %%
def plot_xp_regions(experiments : list, regions : list, colors : list = [], ncols: int = 3):
    """Subplots all regions of a list of experiments (unnormalised)"""
    rows = int(np.ceil(len(regions) / ncols))

    fig, ax = plt.subplots(rows, ncols, figsize=(16, 8))
    for i,r in enumerate(regions):
        for c,xp in enumerate(experiments):
            j, k = i//ncols, i%ncols
            if i == len(regions) - 1:   # Set labels from last region
                li = plot_region(xp, r, ax=ax[j][k], lb=xp.name)
                if len(colors) > 0: li.set_color(colors[c])
                #ax[j][k].set_title('Au_4f')
                ax[j][k].get_legend().remove()
            else:
                li = plot_region(xp, r, ax=ax[j][k], lb='__nolabel__')
                if len(colors) > 0: li.set_color(colors[c])
            ax[j][k].set_title(r)
            cosmetics_plot(ax=ax[j][k], leg = False);
        if len(experiments)%2 == 0:
            ax[j][k].invert_xaxis()
    plt.tight_layout()
    fig.legend(loc='lower right')

# %%
def read_processed_xp(path: str, color: str = None) -> XPS_experiment:
    """Read XPS_experiment class from file"""
    from itertools import islice

    with open(path) as fin:
        head = list(islice(fin, 10))

        delimiters = head[1].split('=')[1][:-1]
        name = head[2].split('=')[1][:-1]
        label = head[3].split('=')[1][:-1]
        date = head[4].split('=')[1][:-1]
        other_meta = head[5].split('=')[1][:-1]

        lindex = 9
        if len(head[6]) > 6:
            area = read_dict_area(head[6])
            color = head[7].split('=')[1][:-1]
        else: area = None
        names = head[lindex].split(',')[1:-1:2]
        dfx = read_processed_dfx(path, names, lindex+2)

    return XPS_experiment(path = path, dfx = dfx, delimiters = delimiters, name = name, color = color,
                                  label = label, date = date, other_meta = other_meta, area = area)

# %% [markdown]
# # Analysis experiments on Cu from september 2020

# %% [markdown]
# ## Read processed experiments

# %%
path = '/Users/pabloherrero/sabat/xps_spectra/FBI_Cu/FBI_subl/**/*.xy'

files = glob.glob(path, recursive=True)
files.sort()
files_new = []
for f in files:
    if ('/proc' in f) and ('2020_10_19' not in f) and ('BaCl' not in f):
        files_new.append(f)
files = files_new
files
# Out:
# ['/Users/pabloherrero/sabat/xps_spectra/FBI_Cu/FBI_subl/2020_09_22_Cu/proc/20200922_Cu_clean2.xy',
#  '/Users/pabloherrero/sabat/xps_spectra/FBI_Cu/FBI_subl/2020_09_22_Cu/proc/20200923_Cu_FBI_subl_20min.xy',
#  '/Users/pabloherrero/sabat/xps_spectra/FBI_Cu/FBI_subl/2020_10_08_Cu/proc/20201013_Cu_FBI_subl_20min.xy',
#  '/Users/pabloherrero/sabat/xps_spectra/FBI_Cu/FBI_subl/2020_10_08_Cu/proc/20201013_Cu_clean2.xy',
#  '/Users/pabloherrero/sabat/xps_spectra/FBI_Cu/FBI_subl/2020_10_14_Cu/proc/20201014_Cu_FBI_subl_25min.xy',
#  '/Users/pabloherrero/sabat/xps_spectra/FBI_Cu/FBI_subl/2020_10_14_Cu/proc/20201014_Cu_FBI_subl_50min.xy',
#  '/Users/pabloherrero/sabat/xps_spectra/FBI_Cu/FBI_subl/2020_10_14_Cu/proc/20201014_Cu_clean.xy',
#  '/Users/pabloherrero/sabat/xps_spectra/FBI_Cu/FBI_subl/2020_10_16_Cu/proc/20201016_Cu_FBI_subl_5min.xy',
#  '/Users/pabloherrero/sabat/xps_spectra/FBI_Cu/FBI_subl/2020_10_16_Cu/proc/20201016_Cu_clean.xy',
#  '/Users/pabloherrero/sabat/xps_spectra/FBI_Cu/FBI_subl/2020_10_21_Cu/proc/20201021_Cu_FBI_subl_15min.xy',
#  '/Users/pabloherrero/sabat/xps_spectra/FBI_Cu/FBI_subl/2020_10_21_Cu/proc/20201021_Cu_clean.xy']

# %%
proc_exps = []
# colors = ['k', 'g', 'b', 'y', 'c']
# for f, c in zip(files, colors):
for f in files:
    proc_exps.append(read_processed_xp(f))

# %%
proc_exps[8].date, proc_exps[8].name
# Out:
# ('2020.10.16', 'Cu_clean4')

# %% [markdown]
# ## Show individual plots

# %%
regions = proc_exps[0].dfx.columns.levels[0].values
regions= ['N_1s', 'C_1s', 'O_1s', 'Ba_3d', 'Cl_2p', 'Cu_2p']

# %%
fbi_exps = [xp for xp in proc_exps if 'clean' not in xp.name]
fbi_exps.pop(4);

# %%
[xp.name for xp in fbi_exps]
# Out:
# ['FBI_sublC_20min',
#  'FBI_sublB_20min',
#  'FBI_sublB_25min',
#  'FBI_sublB_50min',
#  'FBI_sublB_15min']

# %%
plot_xp_regions([proc_exps[0]] + fbi_exps, regions, ncols=3)

# %%
asf
# Out:
# {'C_1s': 0.296,
#  'O_1s': 0.711,
#  'N_1s': 0.477,
#  'Ba_3d': 7.49,
#  'Cu_2p': 5.321,
#  'Cl_2p': 0.891}

# %% [markdown]
# ### Normalized spectra

# %%
def plot_normal_regions(experiments : list, regions : list):
    """Subplots all normalized regions of a list of experiments"""
    rows = int(np.ceil(len(regions) / 3))
    cols = 3
    fig, ax = plt.subplots(rows, cols, figsize=(16, 8))
    for i,r in enumerate(regions):
        for xp in experiments:
            xp_norm = normalise_dfx(xp, inplace=False)
            j, k = i//3, i%3
            if i == len(experiments):   # Set labels from last region
                plot_region(xp_norm, r, ax=ax[j][k], lb=xp_norm.name)
                ax[j][k].set_title('Au_4f')
            else:
                plot_region(xp_norm, r, ax=ax[j][k], lb='__nolabel__')
                ax[j][k].set_title(r)
            cosmetics_plot(ax=ax[j][k], leg = False);
        if len(regions)%2 == 0:
            ax[j][k].invert_xaxis()
    plt.tight_layout()
    fig.legend()

# %%
plot_normal_regions(proc_exps[:2], regions)

# %% [markdown]
# ## Integrate areas

# %%
for xp in proc_exps:
    xp.area = {}

# %% [markdown]
# ### C 1s

# %%
region = 'C_1s'
integrateRegions(proc_exps, region, indRef=1, asf=asf)
# Out:
# /Users/pabloherrero/sabat/sabatsw/xps/xps_analysis.py:61: RuntimeWarning: invalid value encountered in greater
#   dropup = np.where(xp.dfx[region].energy.values > eup)[0]
# [2002.0767165004602,
#  4528.450694499383,
#  10426.517797240962,
#  4125.9392723084275,
#  7777.2751835288345,
#  8778.277774666889,
#  3385.6801835725564,
#  3108.252859247222,
#  3130.14972030019,
#  6136.008153285917,
#  431.1540505922503]

# %% [markdown]
# ### O 1s

# %%
region = 'O_1s'
integrateRegions(proc_exps, region, indRef=2, asf=asf)
# Out:
# /Users/pabloherrero/sabat/sabatsw/xps/xps_analysis.py:61: RuntimeWarning: invalid value encountered in greater
#   dropup = np.where(xp.dfx[region].energy.values > eup)[0]
# [684.7965165574403,
#  2480.3984809412036,
#  4016.7424294777743,
#  1742.0829957402627,
#  3341.3772140477517,
#  3751.6864779611274,
#  1358.0078980712487,
#  2272.0306769180397,
#  1131.439557034889,
#  5439.79499610978,
#  636.4234353446518]

# %% [markdown]
# #### Correct for bg substrate abundance

# %%
for xp in proc_exps[1:9]:
    uncorr_area = xp.area['O_1s']
    xp.area.update({'O_1s': uncorr_area - proc_exps[0].area['O_1s']})

uncorr_area = proc_exps[9].area['O_1s']
proc_exps[9].area.update({'O_1s': uncorr_area - proc_exps[10].area['O_1s']})

# %%
[xp.area['O_1s'] for xp in proc_exps]
# Out:
# [963.1455929077923,
#  2525.4598655186546,
#  4686.281171477263,
#  1487.0414615792156,
#  3736.4004184111277,
#  4313.487990722486,
#  946.8514507929796,
#  2232.3968500149076,
#  628.1899303480292,
#  6755.796850583865,
#  895.1103169404386]

# %% [markdown]
# ### N 1s

# %%
region = 'N_1s'
integrateRegions(proc_exps, region, indRef=2, asf=asf)
# Out:
# [38.79586305691808,
#  512.8932816754148,
#  1375.0284425354591,
#  85.01208078376415,
#  1161.5706588970613,
#  1291.660024927913,
#  73.51034335394031,
#  339.8614858309299,
#  81.5076387730523,
#  1027.8696524789466,
#  28.606814115188136]

# %% [markdown]
# ### Ba 3d

# %%
region = 'Ba_3d'
integrateRegions(proc_exps, region, indRef=2, asf=asf)
# Out:
# [3591.6897817011186,
#  1247.1123259484625,
#  3107.2701187492044,
#  7368.22625087403,
#  6673.772526960159,
#  7259.311341117418,
#  7448.914520483653,
#  5451.558773114897,
#  5932.432198425052,
#  6128.214721652665,
#  1653.8963085641326]

# %% [markdown]
# ### Cl 2p

# %%
region = 'Cl_2p'
integrateRegions(proc_exps, region, indRef=2, asf=asf)
# Out:
# [60.50405695541335,
#  1149.0490759494273,
#  305.51738096740434,
#  145.30832581578622,
#  221.92245387530897,
#  274.76637173097,
#  186.84909889673008,
#  186.77422531813474,
#  200.5971246356471,
#  134.36551566969305,
#  85.805573889626]

# %%
xp.area
# Out:
# {'C_1s': 1456.601522271116,
#  'O_1s': 895.1103169404386,
#  'N_1s': 59.972356635614545,
#  'Ba_3d': 220.81392637705375,
#  'Cl_2p': 96.30255206467565}

# %% [markdown]
# ### Cu 2p

# %%
region = 'Cu_2p'
integrateRegions(proc_exps, region, indRef=2, asf=asf)
# Out:
# [334783.8038293357,
#  333700.06033662264,
#  341344.0813694794,
#  336935.69504488935,
#  357667.24623106205,
#  351235.1499298023,
#  336454.2168855278,
#  345239.7690705367,
#  314334.7663822264,
#  340571.27288109134,
#  328077.8442506449]

# %% [markdown]
# ## Stoichiometry

# %%
num, denom = (('N_1s', 'C_1s', 'C_1s', 'Ba_3d', 'Cu_2p'), ('O_1s', 'N_1s', 'O_1s', 'N_1s', 'N_1s'))
make_stoichometry_table(proc_exps,  num=num, denom=denom)
# Out:
# Experiment	N_/O_	C_/N_	C_/O_	Ba_/N_	Cu_/N_
# Cu_clean	0.08	 83.16	 7.02	 5.90	 773.58
# FBI_sublC_20min	0.43	 14.23	 6.06	 0.15	 58.32
# FBI_sublB_20min	0.62	 12.22	 7.52	 0.14	 22.25
# Cu_clean2	0.12	 78.21	 9.37	 5.52	 355.30
# FBI_sublB_25min	0.65	 10.79	 7.03	 0.37	 27.60
# FBI_sublB_50min	0.63	 10.95	 6.88	 0.36	 24.38
# Cu_clean3	0.16	 74.22	 12.08	 6.45	 410.30
# FBI_sublB_5min	0.32	 14.74	 4.70	 1.02	 91.06
# Cu_clean4	0.27	 61.89	 16.83	 4.64	 345.72
# FBI_sublB_15min	0.32	 9.62	 3.07	 0.38	 29.70
# Cu_clean6	0.07	 24.29	 1.63	 3.68	 1028.09

# %%
print('Nominal')
print('N/O \t C/N \t \t C/O \t O/Cl (ClO4)')
print(3/5, '\t', '%.3f'%(31/3), '\t', '%.3f' %(31/5), '\t %.3f' %(4/1) )
# Out:
# Nominal
# N/O 	 C/N 	 	 C/O 	 O/Cl (ClO4)
# 0.6 	 10.333 	 6.200 	 4.000

# %%
1/59.82
# Out:
# 0.01671681711802073
